# %%
import pandas as pd

# %%
# Load the data from the CSV file into a DataFrame
file_path = '/content/Online Retail.xlsx'
df = pd.read_excel(file_path)

# Display the first few rows of the DataFrame
df.head(20)
# Out:
#    InvoiceNo StockCode1                          Description  Quantity  \
# 0     536365      85123   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365      84406       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365      84029  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365      84029       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     536365      22752         SET 7 BABUSHKA NESTING BOXES         2
# 6     536365      21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7     536366      22633               HAND WARMER UNION JACK         6
# 8     536366      22632            HAND WARMER RED POLKA DOT         6
# 9     536367      84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10    536367      22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11    536367      22748            POPPY'S PLAYHOUSE KITCHEN         6
# 12    536367      22749    FELTCRAFT PRINCESS CHARLOTTE DOLL         8
# 13    536367      22310              IVORY KNITTED MUG COSY          6
# 14    536367      84969   BOX OF 6 ASSORTED COLOUR TEASPOONS         6
# 15    536367      22623        BOX OF VINTAGE JIGSAW BLOCKS          3
# 16    536367      22622       BOX OF VINTAGE ALPHABET BLOCKS         2
# 17    536367      21754             HOME BUILDING BLOCK WORD         3
# 18    536367      21755             LOVE BUILDING BLOCK WORD         3
# 19    536367      21777          RECIPE BOX WITH METAL HEART         4
#
#            InvoiceDate  CustomerID         Country
# 0  2010-12-01 08:26:00     17850.0  United Kingdom
# 1  2010-12-01 08:26:00     17850.0  United Kingdom
# 2  2010-12-01 08:26:00     17850.0  United Kingdom
# 3  2010-12-01 08:26:00     17850.0  United Kingdom
# 4  2010-12-01 08:26:00     17850.0  United Kingdom
# 5  2010-12-01 08:26:00     17850.0  United Kingdom
# 6  2010-12-01 08:26:00     17850.0  United Kingdom
# 7  2010-12-01 08:28:00     17850.0  United Kingdom
# 8  2010-12-01 08:28:00     17850.0  United Kingdom
# 9  2010-12-01 08:34:00     13047.0  United Kingdom
# 10 2010-12-01 08:34:00     13047.0  United Kingdom
# 11 2010-12-01 08:34:00     13047.0  United Kingdom
# 12 2010-12-01 08:34:00     13047.0  United Kingdom
# 13 2010-12-01 08:34:00     13047.0  United Kingdom
# 14 2010-12-01 08:34:00     13047.0  United Kingdom
# 15 2010-12-01 08:34:00     13047.0  United Kingdom
# 16 2010-12-01 08:34:00     13047.0  United Kingdom
# 17 2010-12-01 08:34:00     13047.0  United Kingdom
# 18 2010-12-01 08:34:00     13047.0  United Kingdom
# 19 2010-12-01 08:34:00     13047.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode1   541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   CustomerID   406829 non-null  float64
#  6   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 28.9+ MB

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode1          0
# Description      1454
# Quantity            0
# InvoiceDate         0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# Rename the 'StockCode1' column to 'StockCode'
df.rename(columns={'StockCode1': 'StockCode'}, inplace=True)

# %%
# Remove rows with null values in the 'Description' column
df = df.dropna(subset=['Description'])

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# CustomerID     133626
# Country             0
# dtype: int64

# %%
# Generate a new unique identifier for unknown customers
max_customer_id = df['CustomerID'].astype(float).max()
unknown_customer_id = max_customer_id + 1

# Replace missing values in the 'CustomerID' column with the new identifier
df['CustomerID'].fillna(unknown_customer_id, inplace=True)

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df.head(50)
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365     85123   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365     84406       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6     536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7     536366     22633               HAND WARMER UNION JACK         6
# 8     536366     22632            HAND WARMER RED POLKA DOT         6
# 9     536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10    536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11    536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# 12    536367     22749    FELTCRAFT PRINCESS CHARLOTTE DOLL         8
# 13    536367     22310              IVORY KNITTED MUG COSY          6
# 14    536367     84969   BOX OF 6 ASSORTED COLOUR TEASPOONS         6
# 15    536367     22623        BOX OF VINTAGE JIGSAW BLOCKS          3
# 16    536367     22622       BOX OF VINTAGE ALPHABET BLOCKS         2
# 17    536367     21754             HOME BUILDING BLOCK WORD         3
# 18    536367     21755             LOVE BUILDING BLOCK WORD         3
# 19    536367     21777          RECIPE BOX WITH METAL HEART         4
# 20    536367     48187                  DOORMAT NEW ENGLAND         4
# 21    536368     22960             JAM MAKING SET WITH JARS         6
# 22    536368     22913          RED COAT RACK PARIS FASHION         3
# 23    536368     22912       YELLOW COAT RACK PARIS FASHION         3
# 24    536368     22914         BLUE COAT RACK PARIS FASHION         3
# 25    536369     21756             BATH BUILDING BLOCK WORD         3
# 26    536370     22728            ALARM CLOCK BAKELIKE PINK        24
# 27    536370     22727            ALARM CLOCK BAKELIKE RED         24
# 28    536370     22726           ALARM CLOCK BAKELIKE GREEN        12
# 29    536370     21724      PANDA AND BUNNIES STICKER SHEET        12
# 30    536370     21883                     STARS GIFT TAPE         24
# 31    536370     10002          INFLATABLE POLITICAL GLOBE         48
# 32    536370     21791   VINTAGE HEADS AND TAILS CARD GAME         24
# 33    536370     21035      SET/2 RED RETROSPOT TEA TOWELS         18
# 34    536370     22326  ROUND SNACK BOXES SET OF4 WOODLAND         24
# 35    536370     22629                  SPACEBOY LUNCH BOX         24
# 36    536370     22659              LUNCH BOX I LOVE LONDON        24
# 37    536370     22631             CIRCUS PARADE LUNCH BOX         24
# 38    536370     22661      CHARLOTTE BAG DOLLY GIRL DESIGN        20
# 39    536370     21731        RED TOADSTOOL LED NIGHT LIGHT        24
# 40    536370     22900      SET 2 TEA TOWELS I LOVE LONDON         24
# 41    536370     21913       VINTAGE SEASIDE JIGSAW PUZZLES        12
# 42    536370     22540           MINI JIGSAW CIRCUS PARADE         24
# 43    536370     22544                 MINI JIGSAW SPACEBOY        24
# 44    536370     22492              MINI PAINT SET VINTAGE         36
# 45    536370      POST                              POSTAGE         3
# 46    536371     22086      PAPER CHAIN KIT 50'S CHRISTMAS         80
# 47    536372     22632            HAND WARMER RED POLKA DOT         6
# 48    536372     22633               HAND WARMER UNION JACK         6
# 49    536373     85123   WHITE HANGING HEART T-LIGHT HOLDER         6
#
#            InvoiceDate  CustomerID         Country
# 0  2010-12-01 08:26:00     17850.0  United Kingdom
# 1  2010-12-01 08:26:00     17850.0  United Kingdom
# 2  2010-12-01 08:26:00     17850.0  United Kingdom
# 3  2010-12-01 08:26:00     17850.0  United Kingdom
# 4  2010-12-01 08:26:00     17850.0  United Kingdom
# 5  2010-12-01 08:26:00     17850.0  United Kingdom
# 6  2010-12-01 08:26:00     17850.0  United Kingdom
# 7  2010-12-01 08:28:00     17850.0  United Kingdom
# 8  2010-12-01 08:28:00     17850.0  United Kingdom
# 9  2010-12-01 08:34:00     13047.0  United Kingdom
# 10 2010-12-01 08:34:00     13047.0  United Kingdom
# 11 2010-12-01 08:34:00     13047.0  United Kingdom
# 12 2010-12-01 08:34:00     13047.0  United Kingdom
# 13 2010-12-01 08:34:00     13047.0  United Kingdom
# 14 2010-12-01 08:34:00     13047.0  United Kingdom
# 15 2010-12-01 08:34:00     13047.0  United Kingdom
# 16 2010-12-01 08:34:00     13047.0  United Kingdom
# 17 2010-12-01 08:34:00     13047.0  United Kingdom
# 18 2010-12-01 08:34:00     13047.0  United Kingdom
# 19 2010-12-01 08:34:00     13047.0  United Kingdom
# 20 2010-12-01 08:34:00     13047.0  United Kingdom
# 21 2010-12-01 08:34:00     13047.0  United Kingdom
# 22 2010-12-01 08:34:00     13047.0  United Kingdom
# 23 2010-12-01 08:34:00     13047.0  United Kingdom
# 24 2010-12-01 08:34:00     13047.0  United Kingdom
# 25 2010-12-01 08:35:00     13047.0  United Kingdom
# 26 2010-12-01 08:45:00     12583.0          France
# 27 2010-12-01 08:45:00     12583.0          France
# 28 2010-12-01 08:45:00     12583.0          France
# 29 2010-12-01 08:45:00     12583.0          France
# 30 2010-12-01 08:45:00     12583.0          France
# 31 2010-12-01 08:45:00     12583.0          France
# 32 2010-12-01 08:45:00     12583.0          France
# 33 2010-12-01 08:45:00     12583.0          France
# 34 2010-12-01 08:45:00     12583.0          France
# 35 2010-12-01 08:45:00     12583.0          France
# 36 2010-12-01 08:45:00     12583.0          France
# 37 2010-12-01 08:45:00     12583.0          France
# 38 2010-12-01 08:45:00     12583.0          France
# 39 2010-12-01 08:45:00     12583.0          France
# 40 2010-12-01 08:45:00     12583.0          France
# 41 2010-12-01 08:45:00     12583.0          France
# 42 2010-12-01 08:45:00     12583.0          France
# 43 2010-12-01 08:45:00     12583.0          France
# 44 2010-12-01 08:45:00     12583.0          France
# 45 2010-12-01 08:45:00     12583.0          France
# 46 2010-12-01 09:00:00     13748.0  United Kingdom
# 47 2010-12-01 09:01:00     17850.0  United Kingdom
# 48 2010-12-01 09:01:00     17850.0  United Kingdom
# 49 2010-12-01 09:02:00     17850.0  United Kingdom

# %%
# Convert to numeric and remove rows with non-numeric values
df['InvoiceNo'] = pd.to_numeric(df['InvoiceNo'], errors='coerce')
df['StockCode'] = pd.to_numeric(df['StockCode'], errors='coerce')
df.dropna(subset=['InvoiceNo', 'StockCode'], inplace=True)

# %%
# Ensure InvoiceNo and StockCode are int64
df['InvoiceNo'] = df['InvoiceNo'].astype('int64')
df['StockCode'] = df['StockCode'].astype('int64')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df['Quantity'] = scaler.fit_transform(df[['Quantity']])

# %%
# Using the IQR method to detect outliers in 'Quantity'
Q1 = df['Quantity'].quantile(0.25)
Q3 = df['Quantity'].quantile(0.75)
IQR = Q3 - Q1

# %%
# Define outlier range
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
# Filter out outliers
df = df[(df['Quantity'] >= lower_bound) & (df['Quantity'] <= upper_bound)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 501150 entries, 0 to 541908
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    501150 non-null  int64
#  1   StockCode    501150 non-null  int64
#  2   Description  501150 non-null  object
#  3   Quantity     501150 non-null  float64
#  4   InvoiceDate  501150 non-null  datetime64[ns]
#  5   CustomerID   501150 non-null  float64
#  6   Country      501150 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 30.6+ MB

# %%
df.head(50)
# Out:
#     InvoiceNo  StockCode                          Description  Quantity  \
# 0      536365      85123   WHITE HANGING HEART T-LIGHT HOLDER  0.106032
# 1      536365      71053                  WHITE METAL LANTERN  0.106032
# 2      536365      84406       CREAM CUPID HEARTS COAT HANGER  0.106054
# 3      536365      84029  KNITTED UNION FLAG HOT WATER BOTTLE  0.106032
# 4      536365      84029       RED WOOLLY HOTTIE WHITE HEART.  0.106032
# 5      536365      22752         SET 7 BABUSHKA NESTING BOXES  0.105988
# 6      536365      21730    GLASS STAR FROSTED T-LIGHT HOLDER  0.106032
# 7      536366      22633               HAND WARMER UNION JACK  0.106032
# 8      536366      22632            HAND WARMER RED POLKA DOT  0.106032
# 10     536367      22745           POPPY'S PLAYHOUSE BEDROOM   0.106032
# 11     536367      22748            POPPY'S PLAYHOUSE KITCHEN  0.106032
# 12     536367      22749    FELTCRAFT PRINCESS CHARLOTTE DOLL  0.106054
# 13     536367      22310              IVORY KNITTED MUG COSY   0.106032
# 14     536367      84969   BOX OF 6 ASSORTED COLOUR TEASPOONS  0.106032
# 15     536367      22623        BOX OF VINTAGE JIGSAW BLOCKS   0.105999
# 16     536367      22622       BOX OF VINTAGE ALPHABET BLOCKS  0.105988
# 17     536367      21754             HOME BUILDING BLOCK WORD  0.105999
# 18     536367      21755             LOVE BUILDING BLOCK WORD  0.105999
# 19     536367      21777          RECIPE BOX WITH METAL HEART  0.106010
# 20     536367      48187                  DOORMAT NEW ENGLAND  0.106010
# 21     536368      22960             JAM MAKING SET WITH JARS  0.106032
# 22     536368      22913          RED COAT RACK PARIS FASHION  0.105999
# 23     536368      22912       YELLOW COAT RACK PARIS FASHION  0.105999
# 24     536368      22914         BLUE COAT RACK PARIS FASHION  0.105999
# 25     536369      21756             BATH BUILDING BLOCK WORD  0.105999
# 26     536370      22728            ALARM CLOCK BAKELIKE PINK  0.106231
# 27     536370      22727            ALARM CLOCK BAKELIKE RED   0.106231
# 28     536370      22726           ALARM CLOCK BAKELIKE GREEN  0.106099
# 29     536370      21724      PANDA AND BUNNIES STICKER SHEET  0.106099
# 30     536370      21883                     STARS GIFT TAPE   0.106231
# 32     536370      21791   VINTAGE HEADS AND TAILS CARD GAME   0.106231
# 33     536370      21035      SET/2 RED RETROSPOT TEA TOWELS   0.106165
# 34     536370      22326  ROUND SNACK BOXES SET OF4 WOODLAND   0.106231
# 35     536370      22629                  SPACEBOY LUNCH BOX   0.106231
# 36     536370      22659              LUNCH BOX I LOVE LONDON  0.106231
# 37     536370      22631             CIRCUS PARADE LUNCH BOX   0.106231
# 38     536370      22661      CHARLOTTE BAG DOLLY GIRL DESIGN  0.106187
# 39     536370      21731        RED TOADSTOOL LED NIGHT LIGHT  0.106231
# 40     536370      22900      SET 2 TEA TOWELS I LOVE LONDON   0.106231
# 41     536370      21913       VINTAGE SEASIDE JIGSAW PUZZLES  0.106099
# 42     536370      22540           MINI JIGSAW CIRCUS PARADE   0.106231
# 43     536370      22544                 MINI JIGSAW SPACEBOY  0.106231
# 47     536372      22632            HAND WARMER RED POLKA DOT  0.106032
# 48     536372      22633               HAND WARMER UNION JACK  0.106032
# 49     536373      85123   WHITE HANGING HEART T-LIGHT HOLDER  0.106032
# 50     536373      71053                  WHITE METAL LANTERN  0.106032
# 51     536373      84406       CREAM CUPID HEARTS COAT HANGER  0.106054
# 52     536373      20679                EDWARDIAN PARASOL RED  0.106032
# 53     536373      37370           RETRO COFFEE MUGS ASSORTED  0.106032
# 54     536373      21871                  SAVE THE PLANET MUG  0.106032
#
#            InvoiceDate  CustomerID         Country
# 0  2010-12-01 08:26:00     17850.0  United Kingdom
# 1  2010-12-01 08:26:00     17850.0  United Kingdom
# 2  2010-12-01 08:26:00     17850.0  United Kingdom
# 3  2010-12-01 08:26:00     17850.0  United Kingdom
# 4  2010-12-01 08:26:00     17850.0  United Kingdom
# 5  2010-12-01 08:26:00     17850.0  United Kingdom
# 6  2010-12-01 08:26:00     17850.0  United Kingdom
# 7  2010-12-01 08:28:00     17850.0  United Kingdom
# 8  2010-12-01 08:28:00     17850.0  United Kingdom
# 10 2010-12-01 08:34:00     13047.0  United Kingdom
# 11 2010-12-01 08:34:00     13047.0  United Kingdom
# 12 2010-12-01 08:34:00     13047.0  United Kingdom
# 13 2010-12-01 08:34:00     13047.0  United Kingdom
# 14 2010-12-01 08:34:00     13047.0  United Kingdom
# 15 2010-12-01 08:34:00     13047.0  United Kingdom
# 16 2010-12-01 08:34:00     13047.0  United Kingdom
# 17 2010-12-01 08:34:00     13047.0  United Kingdom
# 18 2010-12-01 08:34:00     13047.0  United Kingdom
# 19 2010-12-01 08:34:00     13047.0  United Kingdom
# 20 2010-12-01 08:34:00     13047.0  United Kingdom
# 21 2010-12-01 08:34:00     13047.0  United Kingdom
# 22 2010-12-01 08:34:00     13047.0  United Kingdom
# 23 2010-12-01 08:34:00     13047.0  United Kingdom
# 24 2010-12-01 08:34:00     13047.0  United Kingdom
# 25 2010-12-01 08:35:00     13047.0  United Kingdom
# 26 2010-12-01 08:45:00     12583.0          France
# 27 2010-12-01 08:45:00     12583.0          France
# 28 2010-12-01 08:45:00     12583.0          France
# 29 2010-12-01 08:45:00     12583.0          France
# 30 2010-12-01 08:45:00     12583.0          France
# 32 2010-12-01 08:45:00     12583.0          France
# 33 2010-12-01 08:45:00     12583.0          France
# 34 2010-12-01 08:45:00     12583.0          France
# 35 2010-12-01 08:45:00     12583.0          France
# 36 2010-12-01 08:45:00     12583.0          France
# 37 2010-12-01 08:45:00     12583.0          France
# 38 2010-12-01 08:45:00     12583.0          France
# 39 2010-12-01 08:45:00     12583.0          France
# 40 2010-12-01 08:45:00     12583.0          France
# 41 2010-12-01 08:45:00     12583.0          France
# 42 2010-12-01 08:45:00     12583.0          France
# 43 2010-12-01 08:45:00     12583.0          France
# 47 2010-12-01 09:01:00     17850.0  United Kingdom
# 48 2010-12-01 09:01:00     17850.0  United Kingdom
# 49 2010-12-01 09:02:00     17850.0  United Kingdom
# 50 2010-12-01 09:02:00     17850.0  United Kingdom
# 51 2010-12-01 09:02:00     17850.0  United Kingdom
# 52 2010-12-01 09:02:00     17850.0  United Kingdom
# 53 2010-12-01 09:02:00     17850.0  United Kingdom
# 54 2010-12-01 09:02:00     17850.0  United Kingdom

# %%
from google.colab import files

# Define file paths
csv_file_path = '/content/Online Retail.csv'
excel_file_path = '/content/Online Retail.xlsx'

# Export DataFrame to CSV
df.to_csv(csv_file_path, index=False)

# Export DataFrame to Excel
df.to_excel(excel_file_path, index=False)

# Download the files to your local machine
files.download(csv_file_path)
files.download(excel_file_path)
